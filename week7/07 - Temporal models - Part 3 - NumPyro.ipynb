# %% [markdown]
# # Week 7 - Temporal models
#
# ## Part 3: Road traffic - Time-series imputation
#
# In this part, we will specify a simple linear dynamical system (LDS) in Pyro in order to do **imputation** on the freeway occupancy rates. Time-series imputation, and imputation of missing values in general, is a problem that arises very frequently when dealing with real data from real-world problems.
#
# There exist many imputation techniques in the literature, but here we will consider model-based approaches. Since we have a probabilistic model for our problem, all we need to do is to treat the missing observations as latent variables in the model and do inference on them - this is the Bayesian way! (and arguably the best way of properly doing imputation... :-) ) This is because the Bayesian framework provide us with a coherent way for handling missing observations.
#
# The usual imports...

# %%
# !pip install numpyro
# Out:
# Requirement already satisfied: numpyro in /usr/local/lib/python3.6/dist-packages (0.2.4)
# Requirement already satisfied: jax==0.1.57 in /usr/local/lib/python3.6/dist-packages (from numpyro) (0.1.57)
# Requirement already satisfied: jaxlib==0.1.37 in /usr/local/lib/python3.6/dist-packages (from numpyro) (0.1.37)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from numpyro) (4.28.1)
# Requirement already satisfied: fastcache in /usr/local/lib/python3.6/dist-packages (from jax==0.1.57->numpyro) (1.1.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from jax==0.1.57->numpyro) (0.9.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.6/dist-packages (from jax==0.1.57->numpyro) (3.1.0)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.6/dist-packages (from jax==0.1.57->numpyro) (1.17.5)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from jaxlib==0.1.37->numpyro) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from jaxlib==0.1.37->numpyro) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from jaxlib==0.1.37->numpyro) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.0->jaxlib==0.1.37->numpyro) (45.2.0)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model
import seaborn as sns
import time

import numpyro
import numpyro.distributions as dist
from numpyro import handlers
from numpyro.infer import MCMC, NUTS

import jax.numpy as jnp
from jax import random, vmap
from jax.scipy.special import logsumexp
from jax import lax

# fix random generator seed (for reproducibility of results)
np.random.seed(42)

# matplotlib style options
plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# %% [markdown]
# The data consists of time-series of freeway occupancy rates (rows), with length $T=1008$, at 10 different consecutive sensors/detectors (columns). Although we will focus only on the data from a single detector as an example...
#
# Load data:

# %%
df = pd.read_csv("http://mlsm.man.dtu.dk/mbml/PeMS_sample.csv")
df.head()
# Out:
#    # detector400000   detector400001  ...   detector400027   detector400030
# 0            0.0154           0.0054  ...           0.0154           0.0080
# 1            0.0085           0.0051  ...           0.0134           0.0067
# 2            0.0099           0.0056  ...           0.0112           0.0065
# 3            0.0108           0.0045  ...           0.0128           0.0040
# 4            0.0100           0.0037  ...           0.0123           0.0064
#
# [5 rows x 10 columns]

# %% [markdown]
# Some basic data statistics:

# %%
print("Dataset size:", len(df))
print("General statistics:")
df.describe()
# Out:
# Dataset size: 1008
# General statistics:
#        # detector400000   detector400001  ...   detector400027   detector400030
# count       1008.000000      1008.000000  ...       1008.00000      1008.000000
# mean           0.049489         0.044541  ...          0.05583         0.049262
# std            0.030016         0.047490  ...          0.04192         0.042152
# min            0.005300         0.000000  ...          0.00150         0.001500
# 25%            0.027150         0.014900  ...          0.01820         0.027075
# 50%            0.055300         0.038600  ...          0.05665         0.046700
# 75%            0.064400         0.051900  ...          0.07670         0.058925
# max            0.317600         0.355000  ...          0.22060         0.408100
#
# [8 rows x 10 columns]

# %% [markdown]
# Visualize data (part of it):

# %%
plt.plot(df[:(2*24*6)]) # first 2 days (2*24*6 10-minute intervals) of each of the 10 detectors
plt.legend(df.columns);

# %% [markdown]
# Lets now generate some articial missing data at random. To make things challenging, will consider a difficult setting were **80% of the observations are missing**.
#
# Notice that we save the real observations for the 80% missings, in order to evaluate the accuracy of our imputations later on.

# %%
# convert data to a matrix
y = df.values
y = y[:(6*24*1)]
N, D = y.shape
print("N=%d, D=%d" % (N,D))
# Out:
# N=144, D=10

# %%
missing_perc = 0.8 # missing percentage

perm1 = np.random.permutation(N)
ix_mis1 = perm1[:int(missing_perc * N)] # missing indexes
ix_obs1 = perm1[int(missing_perc * N):] # observed indexes
y_mis1 = y[ix_mis1,7] #Using data in column 7 (ID=detector400026)
y_obs1 = y[ix_obs1,7]  

N_obs = len(ix_obs1)
N_mis = len(ix_mis1)
N = N_obs + N_mis
print("N_obs:", N_obs)
print("N_mis:", N_mis)
# Out:
# N_obs: 29
# N_mis: 115

# %% [markdown]
# Ok, time to go to Pyro!
#
# Implementing imputation in Pyro requires you to notice that you must tell Pyro which observations are missings so that we can use `numpyro.sample` statement, and let Pyro compute their posterior distribution (inference). In a way, this is similar to what we did in the forecasting notebook, where we told Pyro that there exist these extra "T_forecast" variables, `z_collection[T:T_forecast]`,which follow the same dynamics as the previous z's, and that Pyro should do inference on them (remember, this is done by specifying `numpyro.sample` with `obs=None`).
#
# In the case of time-series imputation, we will do the following:
# -  Besides the observed values (y_obs), we will pass Pyro two arrays: one with the indexes of the time-series that are observed (ix_obs), and another with missing indexes (ix_mis).
# - Amongst the `numpyro.sample` statements, we need to specify which variables we want Pyro to do inference on. Therefore, this block must include, among others, an array "y_mis" with the missing observations from the time-series.
#
# For the purpose of demonstration, we will use a simple autoregressive model of order 1, AR(1), of the form:
#
# \begin{align}
# z_t &\sim \mathcal{N}(\beta z_{t-1}, \tau^2)\\
# y_t &\sim \mathcal{N}(z_t, \sigma^2)
# \end{align}
#
# Now, it is your turn! As for the previous notebook, we provide you the `f` function for the `jax.lax.scan` method. Can you write the Pyro program? We know it is an intimidating task at first, so do not hesitate to ask questions and clarifications! :-)

# %%
def f(carry, noise_t):
  beta, z_prev, tau = carry
  z_t = beta*z_prev + tau*noise_t
  z_prev = z_t
  return (beta, z_prev, tau), z_t

# %%
def model(T, T_forecast, obs=None, ix_mis=None, ix_obs=None):
    """
    Define priors over beta, tau, noises, sigma, z_1 (keep the shapes in mind)
    """
    # Your code here
    """
    Propagate the dynamics forward using jax.lax.scan
    """
    # Your code here
    """
    Sample the observed y (y_obs) and missing y (y_mis)
    """
    # Your code here

# %% [markdown]
# Run inference using MCMC:

# %%
t0 = time.time()

rng_key = random.PRNGKey(0)
rng_key, rng_key_ = random.split(rng_key)

nuts_kernel = NUTS(model=model)
mcmc = MCMC(nuts_kernel, num_samples=1000, num_warmup=1000, num_chains=1)
mcmc.run(rng_key_, T=N, T_forecast=0, obs=y[:,7], ix_mis=ix_mis1, ix_obs=ix_obs1)

t_fin = time.time()

print("Total time: {0:.3f}m".format((t_fin - t0)/60))
# Out:
# sample: 100%|██████████| 2000/2000 [00:33<00:00, 60.10it/s, 511 steps of size 1.40e-02. acc. prob=0.82]
# Total time: 0.671m

# %%
mcmc.print_summary()
# Out:
#                  mean       std    median      5.0%     95.0%     n_eff     r_hat
#        beta      0.98      0.01      0.98      0.96      1.00    265.73      1.01
#   noises[0]      0.07      0.92      0.09     -1.66      1.39    900.50      1.00
#   noises[1]      0.00      0.95      0.05     -1.53      1.49    795.08      1.00
#   noises[2]     -0.00      0.95      0.03     -1.53      1.49    677.29      1.00
#   noises[3]     -0.04      0.92     -0.01     -1.59      1.39    813.91      1.00
#   noises[4]     -0.08      0.94     -0.10     -1.47      1.62    670.71      1.00
#   noises[5]     -0.03      0.96     -0.04     -1.57      1.53   1015.78      1.00
#   noises[6]     -0.03      0.98     -0.03     -1.57      1.61    599.15      1.00
#   noises[7]     -0.05      0.96     -0.03     -1.75      1.42    953.92      1.00
#   noises[8]     -0.07      0.98     -0.12     -1.66      1.44    667.08      1.00
#   noises[9]     -0.03      0.94     -0.03     -1.55      1.48    953.67      1.00
#  noises[10]     -0.02      0.93     -0.05     -1.48      1.66    892.61      1.00
#  noises[11]     -0.09      0.98     -0.14     -1.78      1.45    677.05      1.00
#  noises[12]     -0.02      0.94     -0.03     -1.51      1.51    629.51      1.00
#  noises[13]     -0.02      0.96     -0.05     -1.50      1.58    445.00      1.00
#  noises[14]     -0.04      0.95     -0.06     -1.53      1.51    640.89      1.00
#  noises[15]     -0.04      0.91     -0.06     -1.61      1.32   1146.61      1.00
#  noises[16]      0.01      0.96      0.01     -1.40      1.78    923.08      1.00
#  noises[17]     -0.02      0.94     -0.01     -1.68      1.33   1227.02      1.00
#  noises[18]      0.01      0.95     -0.01     -1.38      1.61    972.74      1.00
#  noises[19]     -0.06      0.91     -0.04     -1.48      1.51    727.44      1.00
#  noises[20]     -0.07      0.70     -0.08     -1.26      1.04    694.15      1.00
#  noises[21]      0.09      0.96      0.07     -1.48      1.70    618.94      1.00
#  noises[22]      0.07      0.97      0.06     -1.52      1.62    725.62      1.00
#  noises[23]      0.07      0.92      0.05     -1.48      1.55    900.62      1.00
#  noises[24]      0.07      0.95      0.10     -1.56      1.52    757.90      1.00
#  noises[25]     -0.07      1.05     -0.02     -1.63      1.83    239.19      1.00
#  noises[26]      0.01      0.93      0.04     -1.71      1.37    799.10      1.00
#  noises[27]      0.05      0.97      0.04     -1.59      1.59    709.00      1.00
#  noises[28]      0.04      0.95      0.05     -1.47      1.58    658.01      1.00
#  noises[29]      0.06      0.83      0.12     -1.27      1.52    605.73      1.00
#  noises[30]      0.06      0.85      0.02     -1.35      1.52   1049.28      1.00
#  noises[31]      0.09      0.91      0.12     -1.48      1.45    735.23      1.00
#  noises[32]      0.16      0.91      0.16     -1.31      1.66    808.66      1.00
#  noises[33]      0.18      0.90      0.19     -1.20      1.63    785.54      1.00
#  noises[34]      0.17      0.90      0.16     -1.34      1.55    702.05      1.00
#  noises[35]      0.17      0.86      0.15     -1.00      1.84    982.75      1.00
#  noises[36]      0.19      0.93      0.25     -1.36      1.58    818.26      1.00
#  noises[37]      0.31      1.04      0.36     -1.33      2.02    617.99      1.00
#  noises[38]      0.22      0.99      0.24     -1.51      1.68    597.85      1.00
#  noises[39]      0.14      1.04      0.14     -1.67      1.74    673.55      1.00
#  noises[40]      0.20      0.98      0.19     -1.42      1.78    654.28      1.00
#  noises[41]      0.23      0.98      0.26     -1.30      1.92    809.68      1.00
#  noises[42]      0.21      0.99      0.18     -1.25      1.78    544.11      1.00
#  noises[43]      0.21      1.00      0.25     -1.60      1.65    672.43      1.00
#  noises[44]      0.21      0.99      0.18     -1.60      1.61    471.84      1.00
#  noises[45]      0.13      0.94      0.13     -1.15      1.96    843.07      1.00
#  noises[46]      0.20      0.99      0.18     -1.27      1.97    819.98      1.00
#  noises[47]      0.26      0.92      0.27     -1.29      1.72    891.47      1.00
#  noises[48]      0.33      1.01      0.33     -1.41      1.81    524.57      1.00
#  noises[49]      0.26      0.98      0.28     -1.33      1.94    873.74      1.00
#  noises[50]      0.28      0.97      0.24     -1.43      1.74    647.32      1.00
#  noises[51]      0.16      1.08      0.24     -1.49      1.93    162.00      1.00
#  noises[52]     -0.02      0.91     -0.03     -1.61      1.30    814.05      1.00
#  noises[53]      0.09      0.88      0.11     -1.29      1.51    569.16      1.00
#  noises[54]      0.06      0.85      0.04     -1.37      1.42   1231.59      1.00
#  noises[55]      0.03      1.01      0.04     -1.58      1.83    247.46      1.00
#  noises[56]      0.07      0.88      0.07     -1.24      1.62    784.62      1.00
#  noises[57]     -0.01      0.81     -0.00     -1.39      1.25    964.21      1.00
#  noises[58]      0.02      0.86     -0.02     -1.40      1.44    712.38      1.00
#  noises[59]      0.00      0.90     -0.02     -1.51      1.39    812.66      1.00
#  noises[60]      0.09      0.87      0.12     -1.36      1.38    659.20      1.00
#  noises[61]      0.06      0.85      0.06     -1.39      1.37   1069.10      1.00
#  noises[62]      0.06      0.91      0.09     -1.60      1.36    428.43      1.00
#  noises[63]      0.15      0.96      0.12     -1.34      1.78    694.45      1.00
#  noises[64]      0.21      0.95      0.19     -1.26      1.75    452.45      1.00
#  noises[65]      0.15      1.01      0.10     -1.47      1.76   1213.31      1.00
#  noises[66]      0.15      0.92      0.17     -1.31      1.75    817.74      1.00
#  noises[67]      0.16      0.96      0.18     -1.56      1.61    359.92      1.00
#  noises[68]      0.16      0.99      0.12     -1.38      1.77    782.78      1.00
#  noises[69]      0.19      0.98      0.26     -1.40      1.76    753.41      1.00
#  noises[70]      0.15      0.94      0.16     -1.45      1.63    365.75      1.01
#  noises[71]      0.12      0.86      0.14     -1.41      1.39    865.84      1.00
#  noises[72]      0.19      0.88      0.19     -1.26      1.68    859.80      1.00
#  noises[73]      0.21      0.84      0.18     -1.17      1.59    923.30      1.00
#  noises[74]      0.14      0.72      0.16     -1.24      1.22    821.77      1.00
#  noises[75]      0.26      0.93      0.30     -1.31      1.75    622.17      1.00
#  noises[76]      0.22      1.00      0.16     -1.54      1.74    720.03      1.00
#  noises[77]      0.20      1.00      0.18     -1.34      1.91    483.85      1.00
#  noises[78]      0.28      0.94      0.27     -1.20      1.77   1014.41      1.00
#  noises[79]      0.18      0.98      0.18     -1.56      1.69   1033.88      1.00
#  noises[80]      0.21      0.98      0.20     -1.54      1.62    491.33      1.01
#  noises[81]      0.20      0.93      0.18     -1.22      1.79   1107.18      1.00
#  noises[82]      0.21      1.00      0.20     -1.34      1.95    810.35      1.00
#  noises[83]      0.23      0.96      0.21     -1.17      1.85    612.91      1.00
#  noises[84]      0.26      0.92      0.26     -1.32      1.74    712.65      1.00
#  noises[85]      0.29      0.94      0.28     -1.23      1.86    830.33      1.00
#  noises[86]      0.24      1.00      0.26     -1.22      2.02    285.73      1.00
#  noises[87]      0.51      0.95      0.51     -1.04      2.06    675.59      1.00
#  noises[88]      0.40      0.95      0.43     -1.14      1.90    938.37      1.00
#  noises[89]      0.39      0.91      0.39     -0.99      1.95    770.53      1.01
#  noises[90]      0.41      0.95      0.43     -1.31      1.78    346.82      1.00
#  noises[91]      0.39      0.85      0.31     -0.95      1.88    594.46      1.00
#  noises[92]      0.36      0.92      0.40     -1.19      1.76    632.09      1.00
#  noises[93]      0.28      0.93      0.26     -1.02      2.03    832.45      1.00
#  noises[94]      0.33      0.99      0.34     -1.51      1.84    820.84      1.00
#  noises[95]      0.37      0.89      0.32     -1.04      1.81    902.61      1.00
#  noises[96]      0.35      0.93      0.35     -1.33      1.69    282.32      1.00
#  noises[97]      0.37      0.95      0.38     -1.12      1.92    519.45      1.00
#  noises[98]      0.32      0.92      0.31     -1.09      1.88    600.40      1.00
#  noises[99]      0.74      0.93      0.69     -0.62      2.37    666.34      1.00
# noises[100]      0.72      0.92      0.67     -0.91      2.15    854.39      1.00
# noises[101]      0.84      0.85      0.85     -0.50      2.25    832.09      1.00
# noises[102]      2.31      0.95      2.33      0.81      3.91     56.94      1.02
# noises[103]      0.73      0.90      0.72     -0.71      2.20    695.81      1.00
# noises[104]      0.69      0.86      0.70     -0.70      2.12    928.93      1.00
# noises[105]      0.66      0.88      0.67     -0.85      1.90    939.88      1.00
# noises[106]      0.64      0.88      0.67     -0.90      1.94    151.55      1.02
# noises[107]     -0.75      1.00     -0.73     -2.20      1.13    609.07      1.00
# noises[108]     -0.70      0.95     -0.69     -2.17      0.90    660.67      1.00
# noises[109]     -0.73      0.93     -0.71     -2.15      0.93    515.64      1.00
# noises[110]     -0.69      0.95     -0.65     -2.31      0.75   1044.84      1.00
# noises[111]     -0.83      0.97     -0.84     -2.33      0.86    824.88      1.00
# noises[112]     -0.77      0.94     -0.77     -2.19      0.81   1016.52      1.00
# noises[113]     -0.76      1.00     -0.78     -2.20      1.02    853.94      1.00
# noises[114]     -0.83      0.99     -0.84     -2.34      0.88    832.76      1.00
# noises[115]     -0.81      0.98     -0.79     -2.47      0.72    283.61      1.01
# noises[116]     -0.20      0.96     -0.26     -1.67      1.38    845.24      1.00
# noises[117]     -0.20      0.93     -0.19     -1.70      1.25    759.06      1.00
# noises[118]     -0.08      0.89     -0.02     -1.61      1.27    642.58      1.00
# noises[119]     -0.17      0.95     -0.21     -1.66      1.40    731.89      1.00
# noises[120]     -0.12      0.89     -0.09     -1.52      1.30    467.38      1.00
# noises[121]     -0.14      0.92     -0.14     -1.72      1.20    577.66      1.00
# noises[122]     -0.18      0.90     -0.23     -1.63      1.31    693.66      1.00
# noises[123]     -0.16      0.90     -0.18     -1.44      1.43    692.66      1.00
# noises[124]     -0.12      0.93     -0.10     -1.57      1.38    636.78      1.00
# noises[125]     -0.08      0.91     -0.10     -1.51      1.43    466.23      1.00
# noises[126]      0.07      0.82      0.08     -1.20      1.36    653.71      1.00
# noises[127]      0.01      0.83      0.05     -1.38      1.22    665.64      1.00
# noises[128]     -0.12      0.79     -0.08     -1.43      1.17    979.97      1.00
# noises[129]     -0.10      0.81     -0.07     -1.29      1.33   1171.56      1.00
# noises[130]     -0.14      0.94     -0.13     -1.61      1.41    926.70      1.00
# noises[131]     -0.15      0.90     -0.16     -1.58      1.24   1067.85      1.00
# noises[132]     -0.13      0.87     -0.14     -1.49      1.31    729.93      1.00
# noises[133]     -0.22      0.93     -0.20     -1.77      1.28    801.33      1.00
# noises[134]     -0.10      0.91     -0.10     -1.57      1.35    759.52      1.00
# noises[135]     -0.06      0.93     -0.06     -1.32      1.78    326.40      1.01
# noises[136]     -0.10      0.92     -0.14     -1.61      1.34    730.06      1.00
# noises[137]     -0.14      0.85     -0.14     -1.55      1.22    669.61      1.00
# noises[138]     -0.09      0.87     -0.08     -1.55      1.35    979.07      1.00
# noises[139]     -0.14      0.96     -0.14     -1.50      1.54    385.84      1.00
# noises[140]     -0.12      0.91     -0.12     -1.60      1.38    870.91      1.00
# noises[141]     -0.09      0.96     -0.10     -1.80      1.38    710.26      1.00
# noises[142]     -0.07      0.90     -0.07     -1.59      1.36    801.32      1.00
#       sigma      0.01      0.00      0.01      0.01      0.02     25.53      1.05
#         tau      0.01      0.00      0.01      0.01      0.02    169.37      1.01
#    y_mis[0]      0.08      0.02      0.08      0.05      0.12    550.11      1.00
#    y_mis[1]      0.01      0.02      0.01     -0.03      0.04    774.17      1.00
#    y_mis[2]      0.08      0.03      0.08      0.03      0.12    442.32      1.00
#    y_mis[3]      0.12      0.02      0.12      0.08      0.15    454.62      1.00
#    y_mis[4]      0.05      0.02      0.05      0.03      0.09    806.34      1.00
#    y_mis[5]      0.01      0.03      0.01     -0.04      0.04    463.40      1.00
#    y_mis[6]      0.04      0.02      0.04      0.01      0.08    781.71      1.00
#    y_mis[7]      0.05      0.02      0.06      0.01      0.09    744.94      1.00
#    y_mis[8]      0.06      0.03      0.06      0.01      0.09    660.29      1.00
#    y_mis[9]      0.01      0.02      0.01     -0.03      0.04    902.61      1.00
#   y_mis[10]      0.05      0.02      0.05      0.02      0.10    486.21      1.00
#   y_mis[11]      0.07      0.03      0.07      0.03      0.11    493.46      1.00
#   y_mis[12]      0.11      0.02      0.11      0.07      0.15    696.20      1.00
#   y_mis[13]      0.04      0.02      0.04      0.01      0.08    758.40      1.00
#   y_mis[14]      0.13      0.02      0.13      0.10      0.17    371.14      1.01
#   y_mis[15]      0.05      0.02      0.05      0.02      0.09    777.99      1.00
#   y_mis[16]      0.01      0.02      0.01     -0.04      0.04    645.17      1.00
#   y_mis[17]      0.06      0.02      0.06      0.02      0.10    695.84      1.00
#   y_mis[18]      0.06      0.02      0.05      0.02      0.09    396.37      1.00
#   y_mis[19]      0.06      0.02      0.06      0.02      0.09    843.35      1.00
#   y_mis[20]      0.01      0.03      0.01     -0.03      0.05    353.69      1.00
#   y_mis[21]      0.07      0.02      0.07      0.04      0.11    443.15      1.00
#   y_mis[22]      0.16      0.03      0.16      0.12      0.21    388.12      1.00
#   y_mis[23]      0.12      0.03      0.12      0.08      0.16    511.58      1.00
#   y_mis[24]      0.05      0.02      0.05      0.02      0.09    505.73      1.00
#   y_mis[25]      0.04      0.03      0.04     -0.02      0.09    262.46      1.00
#   y_mis[26]      0.01      0.03      0.01     -0.04      0.06    461.87      1.00
#   y_mis[27]      0.02      0.03      0.02     -0.03      0.06    477.45      1.00
#   y_mis[28]      0.01      0.03      0.01     -0.04      0.05    626.55      1.00
#   y_mis[29]      0.06      0.02      0.06      0.03      0.10    569.09      1.00
#   y_mis[30]      0.01      0.02      0.01     -0.02      0.04    446.80      1.01
#   y_mis[31]      0.12      0.02      0.12      0.09      0.16    585.69      1.00
#   y_mis[32]      0.02      0.02      0.02     -0.02      0.05    620.55      1.00
#   y_mis[33]      0.01      0.02      0.01     -0.03      0.05    913.14      1.00
#   y_mis[34]      0.01      0.03      0.01     -0.04      0.06    410.44      1.00
#   y_mis[35]      0.11      0.02      0.11      0.07      0.14    803.70      1.00
#   y_mis[36]      0.15      0.03      0.15      0.11      0.19    632.42      1.00
#   y_mis[37]      0.03      0.03      0.03     -0.02      0.09    364.89      1.00
#   y_mis[38]      0.08      0.02      0.08      0.04      0.11    302.13      1.00
#   y_mis[39]      0.05      0.02      0.05      0.02      0.08    859.57      1.00
#   y_mis[40]      0.12      0.02      0.12      0.08      0.15    427.19      1.00
#   y_mis[41]      0.05      0.02      0.05      0.02      0.09    703.74      1.00
#   y_mis[42]      0.02      0.02      0.02     -0.02      0.05    648.86      1.00
#   y_mis[43]      0.08      0.03      0.08      0.04      0.12    613.60      1.00
#   y_mis[44]      0.01      0.02      0.01     -0.03      0.04    619.46      1.00
#   y_mis[45]      0.03      0.03      0.03     -0.02      0.08    390.46      1.00
#   y_mis[46]      0.09      0.02      0.09      0.05      0.12    524.49      1.00
#   y_mis[47]      0.01      0.03      0.01     -0.04      0.04    583.81      1.00
#   y_mis[48]      0.01      0.03      0.01     -0.03      0.05    523.52      1.00
#   y_mis[49]      0.01      0.02      0.00     -0.04      0.04    619.43      1.00
#   y_mis[50]      0.10      0.02      0.10      0.06      0.13    490.59      1.02
#   y_mis[51]      0.06      0.03      0.06      0.01      0.09    517.24      1.00
#   y_mis[52]      0.04      0.03      0.04     -0.02      0.08    331.33      1.00
#   y_mis[53]      0.01      0.02      0.01     -0.02      0.04    891.87      1.00
#   y_mis[54]      0.11      0.02      0.11      0.08      0.16    614.52      1.00
#   y_mis[55]      0.03      0.03      0.03     -0.01      0.07    528.53      1.00
#   y_mis[56]      0.00      0.02      0.01     -0.03      0.04    692.47      1.00
#   y_mis[57]      0.06      0.03      0.06      0.01      0.10    554.21      1.00
#   y_mis[58]      0.08      0.03      0.08      0.03      0.12    378.32      1.00
#   y_mis[59]      0.02      0.02      0.03     -0.01      0.06    625.05      1.00
#   y_mis[60]      0.04      0.03      0.04     -0.01      0.09    321.45      1.00
#   y_mis[61]      0.01      0.02      0.01     -0.02      0.04    477.78      1.01
#   y_mis[62]      0.14      0.03      0.14      0.09      0.18    545.47      1.00
#   y_mis[63]      0.07      0.02      0.07      0.03      0.10    567.57      1.00
#   y_mis[64]      0.03      0.02      0.03     -0.00      0.06    836.54      1.00
#   y_mis[65]      0.01      0.02      0.01     -0.02      0.05    864.95      1.00
#   y_mis[66]      0.08      0.03      0.08      0.03      0.12    424.03      1.00
#   y_mis[67]      0.02      0.02      0.02     -0.02      0.06    880.12      1.00
#   y_mis[68]      0.05      0.02      0.05      0.02      0.08    952.57      1.00
#   y_mis[69]      0.03      0.02      0.03     -0.01      0.06    745.12      1.00
#   y_mis[70]      0.03      0.02      0.03      0.00      0.07   1006.75      1.00
#   y_mis[71]      0.05      0.02      0.06      0.02      0.09    772.58      1.00
#   y_mis[72]      0.01      0.03      0.02     -0.04      0.05    480.55      1.00
#   y_mis[73]      0.08      0.02      0.08      0.05      0.12    516.57      1.01
#   y_mis[74]      0.18      0.02      0.17      0.13      0.21    425.29      1.00
#   y_mis[75]      0.05      0.03      0.05      0.00      0.10    393.91      1.00
#   y_mis[76]      0.02      0.02      0.02     -0.02      0.05    527.01      1.00
#   y_mis[77]      0.07      0.02      0.07      0.03      0.11    598.00      1.00
#   y_mis[78]      0.01      0.02      0.01     -0.03      0.05    609.28      1.00
#   y_mis[79]      0.05      0.02      0.05      0.01      0.08   1026.81      1.00
#   y_mis[80]      0.01      0.03      0.01     -0.04      0.06    534.53      1.00
#   y_mis[81]      0.04      0.03      0.04     -0.01      0.09    366.84      1.00
#   y_mis[82]      0.06      0.02      0.06      0.03      0.10    652.31      1.00
#   y_mis[83]      0.10      0.02      0.10      0.06      0.13    419.48      1.00
#   y_mis[84]      0.08      0.03      0.08      0.03      0.12    395.48      1.00
#   y_mis[85]      0.06      0.02      0.06      0.03      0.10    633.12      1.00
#   y_mis[86]      0.05      0.02      0.05      0.02      0.08    894.10      1.00
#   y_mis[87]      0.01      0.03      0.01     -0.04      0.06    495.54      1.00
#   y_mis[88]      0.01      0.02      0.01     -0.03      0.04    502.69      1.00
#   y_mis[89]      0.19      0.02      0.19      0.16      0.23    246.75      1.01
#   y_mis[90]      0.11      0.02      0.11      0.07      0.15    460.10      1.01
#   y_mis[91]      0.02      0.03      0.02     -0.03      0.06    545.38      1.00
#   y_mis[92]      0.01      0.02      0.01     -0.03      0.04    621.70      1.00
#   y_mis[93]      0.02      0.02      0.02     -0.01      0.07    377.89      1.00
#   y_mis[94]      0.06      0.02      0.06      0.03      0.09    985.51      1.00
#   y_mis[95]      0.07      0.02      0.07      0.04      0.11    797.26      1.00
#   y_mis[96]      0.01      0.03      0.01     -0.03      0.06    398.21      1.00
#   y_mis[97]      0.14      0.02      0.14      0.11      0.17    441.08      1.00
#   y_mis[98]      0.02      0.02      0.02     -0.02      0.05    570.69      1.01
#   y_mis[99]      0.06      0.02      0.06      0.03      0.10    622.08      1.00
#  y_mis[100]      0.05      0.02      0.05      0.01      0.09    937.75      1.00
#  y_mis[101]      0.05      0.03      0.05      0.01      0.10    292.24      1.00
#  y_mis[102]      0.18      0.02      0.19      0.15      0.22    218.07      1.01
#  y_mis[103]      0.04      0.03      0.04     -0.01      0.09    287.18      1.00
#  y_mis[104]      0.19      0.02      0.19      0.16      0.22    325.31      1.00
#  y_mis[105]      0.05      0.02      0.05      0.02      0.09    645.15      1.00
#  y_mis[106]      0.02      0.02      0.02     -0.02      0.06    802.04      1.00
#  y_mis[107]      0.07      0.03      0.07      0.04      0.12    332.97      1.00
#  y_mis[108]      0.03      0.02      0.03     -0.00      0.06    549.16      1.00
#  y_mis[109]      0.10      0.02      0.10      0.07      0.14    574.57      1.00
#  y_mis[110]      0.03      0.03      0.03     -0.01      0.09    343.61      1.00
#  y_mis[111]      0.05      0.02      0.05      0.02      0.08    838.05      1.00
#  y_mis[112]      0.10      0.02      0.10      0.07      0.14    522.05      1.00
#  y_mis[113]      0.05      0.03      0.05     -0.00      0.09    404.31      1.00
#  y_mis[114]      0.09      0.02      0.09      0.06      0.13    768.09      1.00
#         z_1      0.02      0.02      0.02     -0.01      0.05    576.82      1.00
#
# Number of divergences: 128

# %% [markdown]
# Extract samples and plot posteriors over some of the latent variables (parameters): beta, tau and sigma

# %%
hmc_samples = {k: v for k, v in mcmc.get_samples().items()}

# %%
nodes = ["beta", "tau", "sigma"]
for node in nodes:
  plt.figure(figsize=(4,3))
  sns.distplot(hmc_samples[node], label=node)
  plt.legend()
  plt.show()

# %% [markdown]
# Compute mean and standard devitions for the imputed values of the time-series and visualize them (in comparison with the corresponding true values):

# %%
# get mean and standard devitions for predictions
y_hat = hmc_samples["y_mis"].mean(axis=0)
y_std = hmc_samples["y_mis"].std(axis=0)

# %%
plt.plot(ix_obs1, y_obs1, "bo")
plt.plot(ix_mis1, y_mis1, "bx")
plt.plot(ix_mis1, y_hat, "rx")
plt.legend(["Observed", "Missing", "Imputed"]);

# %% [markdown]
# Compute error statistics of the model's imputations:

# %%
def compute_error(trues, predicted):
    import numpy
    corr = numpy.corrcoef(predicted, trues)[0,1]
    mae = numpy.mean(np.abs(predicted - trues))
    rae = numpy.sum(numpy.abs(predicted - trues)) / numpy.sum(numpy.abs(trues - numpy.mean(trues)))
    rmse = numpy.sqrt(numpy.mean((predicted - trues)**2))
    r2 = max(0, 1 - numpy.sum((trues-predicted)**2) / numpy.sum((trues - numpy.mean(trues))**2))
    return corr, mae, rae, rmse, r2

# %%
corr, mae, rae, rmse, r2 = compute_error(y_mis1, y_hat)
print("CorrCoef: %.3f\nMAE: %.5f\nRMSE: %.5f\nR2: %.3f" % (corr, mae, rmse, r2))
# Out:
# CorrCoef: 0.897
# MAE: 0.01113
# RMSE: 0.02226
# R2: 0.804

# %% [markdown]
# *Not* too bad... But our model was quite naive. We can definitely do better with a more appropriate model, i.e. that exploits our prior knowledge about this particular problem. That is what we shall do in the next notebook! :-)
